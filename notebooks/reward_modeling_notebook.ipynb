# %% [markdown]
# # 🧠 Reward Modeling with TRL (GPT2 Example)
#
# Converted from the original Hugging Face script for Jupyter Notebook use.

# %%
# Copyright 2020-2025 The HuggingFace Team. All rights reserved.
# Licensed under the Apache License, Version 2.0 (the "License").
#     http://www.apache.org/licenses/LICENSE-2.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
userdata.get('HF_TOKEN')
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### 🧩 1. Install dependencies

# %%
# !pip install -q trl trackio kernels accelerate datasets transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.5/872.5 kB 38.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 128.6 MB/s eta 0:00:00

# %% [markdown]
# ###📚2. Initialize

# %%
model_name = 'gpt2'
output_dir = '/content/drive/Othercomputers/My Mac/Google Drive/Colab Notebooks/Reinforcement-learning/outputs/Gpt2-Reward'

# %% [markdown]
# ### ⚙️ 2. Imports and logging setup

# %%
import os
import torch
from accelerate import logging
from datasets import load_dataset
from transformers import AutoModelForSequenceClassification, HfArgumentParser

from trl import (
    ModelConfig,
    RewardConfig,
    RewardTrainer,
    ScriptArguments,
    get_kbit_device_map,
    get_peft_config,
    get_quantization_config,
)

logger = logging.get_logger(__name__)
os.environ.setdefault("TRACKIO_SPACE_ID", "trl-trackio")
# Out:
# 'trl-trackio'

# %% [markdown]
# ### 📦 3. Define helper configs for notebook runs

# %%
from dataclasses import dataclass

script_args = ScriptArguments(
    dataset_name="Anthropic/hh-rlhf"
)
training_args = RewardConfig(
    output_dir=output_dir,
    per_device_train_batch_size=2,
    num_train_epochs=1,
    gradient_checkpointing=True,
    learning_rate=1e-5,
    eval_strategy="steps",
    eval_steps=50,
    max_length=1024,
)
model_args = ModelConfig(
    model_name_or_path="gpt2",
    # trust_remote_code=True,
)
training_args.gradient_checkpointing_kwargs = dict(use_reentrant=False)

# %% [markdown]
# ### 🧠 4. Load model and tokenizer

# %%
dtype = model_args.dtype if model_args.dtype in ["auto", None] else getattr(torch, model_args.dtype)
model_kwargs = dict(
    revision=model_args.model_revision,
    use_cache=False if training_args.gradient_checkpointing else True,
    dtype=dtype,
)

quantization_config = get_quantization_config(model_args)
if quantization_config is not None:
    model_kwargs["device_map"] = get_kbit_device_map()
    model_kwargs["quantization_config"] = quantization_config

model = AutoModelForSequenceClassification.from_pretrained(
    model_args.model_name_or_path,
    num_labels=1,
    trust_remote_code=model_args.trust_remote_code,
    **model_kwargs,
)

if model_args.use_peft and model_args.lora_task_type != "SEQ_CLS":
    logger.warning(
        "⚠️ PEFT `task_type` differs from SEQ_CLS — this can cause silent bugs."
    )
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### 📚 5. Load dataset

# %%
dataset = load_dataset(script_args.dataset_name, split="train[:10%]")
eval_dataset = dataset.select(range(min(512, len(dataset))))
print(dataset)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# harmless-base/train.jsonl.gz:   0%|          | 0.00/13.2M [00:00<?, ?B/s]
# helpful-base/train.jsonl.gz:   0%|          | 0.00/16.2M [00:00<?, ?B/s]
# helpful-online/train.jsonl.gz:   0%|          | 0.00/20.1M [00:00<?, ?B/s]
# helpful-rejection-sampled/train.jsonl.gz:   0%|          | 0.00/25.7M [00:00<?, ?B/s]
# harmless-base/test.jsonl.gz:   0%|          | 0.00/743k [00:00<?, ?B/s]
# helpful-base/test.jsonl.gz:   0%|          | 0.00/875k [00:00<?, ?B/s]
# helpful-online/test.jsonl.gz:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# helpful-rejection-sampled/test.jsonl.gz:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/160800 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/8552 [00:00<?, ? examples/s]
# Dataset({
#     features: ['chosen', 'rejected'],
#     num_rows: 16080
# })

# %% [markdown]
# ### 🚀 6. Train Reward Model

# %%
trainer = RewardTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    eval_dataset=eval_dataset,
    peft_config=get_peft_config(model_args),
)

trainer.train()
# Out:
# Tokenizing eval dataset:   0%|          | 0/512 [00:00<?, ? examples/s]
# Filtering eval >1024 tokens:   0%|          | 0/512 [00:00<?, ? examples/s]
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: haroonraja86 (haroonraja86-rutgers-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251104_034109-ev094y3h</code>
# Syncing run <strong><a href='https://wandb.ai/haroonraja86-rutgers-university/huggingface/runs/ev094y3h' target="_blank">fallen-dragon-6</a></strong> to <a href='https://wandb.ai/haroonraja86-rutgers-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/haroonraja86-rutgers-university/huggingface' target="_blank">https://wandb.ai/haroonraja86-rutgers-university/huggingface</a>
#  View run at <a href='https://wandb.ai/haroonraja86-rutgers-university/huggingface/runs/ev094y3h' target="_blank">https://wandb.ai/haroonraja86-rutgers-university/huggingface/runs/ev094y3h</a>
# wandb: Detected [huggingface_hub.inference, mcp] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# The `TRACKIO_SPACE_ID` environment variable is deprecated and will be removed in a future version. Use TrainingArguments.trackio_space_id instead.
# * Trackio project initialized: huggingface
# * Trackio metrics will be synced to Hugging Face Dataset: hraja01/trl-trackio-dataset
# * Found existing space: https://huggingface.co/spaces/hraja01/trl-trackio
# * View dashboard by going to: https://hraja01-trl-trackio.hf.space/
# <div><iframe src="https://hraja01-trl-trackio.hf.space/" width="100%" height="1000px" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# * Created new run: hraja01-1762227671
#     <div>
#
#       <progress value='8039' max='8039' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8039/8039 35:49, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Num Tokens</th>
#       <th>Min Reward</th>
#       <th>Mean Reward</th>
#       <th>Max Reward</th>
#       <th>Accuracy</th>
#       <th>Margin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.698300</td>
#       <td>1.021268</td>
#       <td>36141.000000</td>
#       <td>-14.684570</td>
#       <td>-11.308609</td>
#       <td>-7.055908</td>
#       <td>0.542969</td>
#       <td>0.247192</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.969400</td>
#       <td>0.925816</td>
#       <td>69539.000000</td>
#       <td>-13.919922</td>
#       <td>-10.676956</td>
#       <td>-7.016846</td>
#       <td>0.535156</td>
#       <td>0.222748</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.542600</td>
#       <td>0.879920</td>
#       <td>100117.000000</td>
#       <td>-14.907227</td>
#       <td>-11.855652</td>
#       <td>-7.954102</td>
#       <td>0.554688</td>
#       <td>0.299927</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.946700</td>
#       <td>0.878098</td>
#       <td>132631.000000</td>
#       <td>-15.722656</td>
#       <td>-11.971905</td>
#       <td>-7.787781</td>
#       <td>0.580078</td>
#       <td>0.436485</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.716400</td>
#       <td>0.800803</td>
#       <td>165794.000000</td>
#       <td>-15.114258</td>
#       <td>-11.449341</td>
#       <td>-7.718262</td>
#       <td>0.585938</td>
#       <td>0.446045</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.748100</td>
#       <td>0.837236</td>
#       <td>199302.000000</td>
#       <td>-16.201172</td>
#       <td>-12.549530</td>
#       <td>-8.086914</td>
#       <td>0.601562</td>
#       <td>0.529236</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.278000</td>
#       <td>0.960610</td>
#       <td>228099.000000</td>
#       <td>-17.359375</td>
#       <td>-13.486755</td>
#       <td>-7.726562</td>
#       <td>0.583984</td>
#       <td>0.723267</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.619300</td>
#       <td>0.885567</td>
#       <td>264007.000000</td>
#       <td>-16.566406</td>
#       <td>-13.046051</td>
#       <td>-7.852051</td>
#       <td>0.607422</td>
#       <td>0.601257</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.888400</td>
#       <td>0.876218</td>
#       <td>297868.000000</td>
#       <td>-16.055664</td>
#       <td>-11.970520</td>
#       <td>-7.247070</td>
#       <td>0.615234</td>
#       <td>0.617920</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.233800</td>
#       <td>0.826952</td>
#       <td>327943.000000</td>
#       <td>-15.528320</td>
#       <td>-11.449188</td>
#       <td>-7.270508</td>
#       <td>0.630859</td>
#       <td>0.601379</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.533500</td>
#       <td>0.689853</td>
#       <td>887054.000000</td>
#       <td>-14.980469</td>
#       <td>-10.707123</td>
#       <td>-6.954102</td>
#       <td>0.638672</td>
#       <td>0.756653</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.960600</td>
#       <td>0.723560</td>
#       <td>923426.000000</td>
#       <td>-16.071289</td>
#       <td>-11.497936</td>
#       <td>-7.256042</td>
#       <td>0.642578</td>
#       <td>0.869728</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.695100</td>
#       <td>0.739493</td>
#       <td>954409.000000</td>
#       <td>-16.871094</td>
#       <td>-12.802307</td>
#       <td>-8.339355</td>
#       <td>0.642578</td>
#       <td>0.853760</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.815700</td>
#       <td>0.728626</td>
#       <td>986027.000000</td>
#       <td>-17.007812</td>
#       <td>-13.245483</td>
#       <td>-8.903320</td>
#       <td>0.652344</td>
#       <td>0.807373</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.615000</td>
#       <td>0.708413</td>
#       <td>1019754.000000</td>
#       <td>-16.359375</td>
#       <td>-12.352600</td>
#       <td>-8.063965</td>
#       <td>0.640625</td>
#       <td>0.848511</td>
#     </tr>
#     <tr>
#       <td>1600</td>
# Exception in thread Thread-15 (_init_client_background):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/trackio/run.py", line 113, in _init_client_background
#     self._batch_sender()
#   File "/usr/local/lib/python3.12/dist-packages/trackio/run.py", line 84, in _batch_sender
#     self._client.predict(
#   File "/usr/local/lib/python3.12/dist-packages/gradio_client/client.py", line 505, in predict
#     ).result()
#       ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio_client/client.py", line 1610, in result
#     return super().result(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio_client/client.py", line 1214, in _inner
#     predictions = _predict(*data, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio_client/client.py", line 1334, in _predict
#     raise AppError(message=message, **result)
# gradio_client.exceptions.AppError: The read operation timed out
# * Run finished. Uploading logs to Trackio (please wait...)
# TrainOutput(global_step=8039, training_loss=0.7907339241807475, metrics={'train_runtime': 2160.754, 'train_samples_per_second': 7.44, 'train_steps_per_second': 3.72, 'total_flos': 4116066436601856.0, 'train_loss': 0.7907339241807475, 'num_tokens': 5286003.0, 'min_reward': -14.819444444444445, 'mean_reward': -11.598958333333334, 'max_reward': -7.625, 'accuracy': 0.7222222222222222, 'margin': 2.34375, 'epoch': 1.0})

# %%
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### 📊 7. Evaluate and save model

# %%
trainer.save_model(training_args.output_dir)

if training_args.eval_strategy != "no":
    metrics = trainer.evaluate()
    trainer.log_metrics("eval", metrics)
    trainer.save_metrics("eval", metrics)

if training_args.push_to_hub:
    trainer.push_to_hub(dataset_name=script_args.dataset_name)
# Out:
#     <div>
#
#       <progress value='64' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [64/64 00:07]
#     </div>
# ***** eval metrics *****
#   epoch                   =        1.0
#   eval_accuracy           =     0.7227
#   eval_loss               =     0.6538
#   eval_margin             =     1.7722
#   eval_max_reward         =     0.8689
#   eval_mean_reward        =    -4.7103
#   eval_min_reward         =    -10.481
#   eval_num_tokens         =  5286003.0
#   eval_runtime            = 0:00:07.38
#   eval_samples_per_second =       69.3
#   eval_steps_per_second   =      8.662

# %% [markdown]
# ### ✅ 8. Quick inference sanity check

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_args.model_name_or_path)
prompt = "The assistant is polite and helpful."
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

with torch.no_grad():
    reward = model(**inputs).logits.item()

print(f"Reward score: {reward:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3132351496.py in <cell line: 0>()
#       1 from transformers import AutoTokenizer
#       2
# ----> 3 tokenizer = AutoTokenizer.from_pretrained(model_args.model_name_or_path)
#       4 prompt = "The assistant is polite and helpful."
#       5 inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
#
# NameError: name 'model_args' is not defined
