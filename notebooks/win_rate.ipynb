# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm
import pandas as pd
from datasets import load_dataset

# %% [markdown]
# ## Evaluation

# %%
# !python /content/drive/Othercomputers/My\ Mac/Google\ Drive/Colab\ Notebooks/Reinforcement-learning/src/evaluation_suite.py \
  --policy "/content/drive/Othercomputers/My Mac/Google Drive/Colab Notebooks/Reinforcement-learning/outputs/gpt2/checkpoint-6000" \
  --reference "gpt2" \
  --dataset "Anthropic/hh-rlhf" \
  --split "test[:1000]" \
  --batch_size 2 \
  --max_length 1024 \
  --seed 42
# Out:
# 2025-11-10 21:54:11.572617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762811651.599661   28126 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762811651.609846   28126 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762811651.627817   28126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
torch.cuda.empty_cache()
